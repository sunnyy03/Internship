# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException , ElementClickInterceptedException

#importing time
import time

#Importing requests
import requests

#importing warnings
import warnings
warnings.filterwarnings('ignore')

# importing regex
import re

#importing keys
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

#importing action chains
from selenium.webdriver import ActionChains

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

# %% [markdown]
# -So, we are going to scrape data for some routes on various dates

# %% [markdown]
# New Delhi To Mumbai

# %%
#loading the website on automated window

driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1659545600598&viewName=normal")

# %%
#making empty lists
airline = []   
depart = []
arrival = []
source = []
destination = []
duration = []
stops = []
price = []
date = []

# %%
#scrolling to the bottom of the page
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")            

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 69 69 69 69 69 69 69 69 69

# %%
driver.execute_script("window.scrollTo(0, 0);")
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 94 94 94 94 94 94 94 94

# %%
driver.execute_script("window.scrollTo(0, 0);")
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 252 252 252 252 252 252 252 252 252

# %% [markdown]
# -loading a month after date flights

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=01%2F09%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1659598273666&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 425 425 425 425 425 425 425 425

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 594 594 594 594 594 594 594 594

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 619 619 619 619 619 619 619 619

# %% [markdown]
# -For Banglore to Kolkata

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=258854970527&version=1.1&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 673 673 673 673 673 673 673 673

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 779 779 779 779 779 779 779 779

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 901 901 901 901 901 901 901 901

# %% [markdown]
# -loading a month after date flights

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price))
# Out:
# 1039 1039 1039 1039 1039 1039 1039 1039

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1064 1064 1064 1064 1064 1064 1064 1064 1064

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1202 1202 1202 1202 1202 1204 1202 1202 1202

# %% [markdown]
# -For New Delhi to Kolkata

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=867334761583&version=1.1&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1259 1259 1259 1259 1259 1259 1259 1259 1259

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height


#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1370 1370 1370 1370 1370 1370 1370 1370 1370

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1494 1494 1494 1494 1494 1494 1494 1494 1494

# %% [markdown]
# -loading a month after date flights

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1634 1634 1634 1634 1634 1634 1634 1634 1634

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1773 1773 1773 1773 1773 1773 1773 1773 1773

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1914 1914 1914 1914 1914 1914 1914 1914 1914

# %% [markdown]
# -For Mumbai to Banglore

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=406306423506&version=1.56&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 1977 1977 1977 1977 1977 1977 1977 1977 1977

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2097 2097 2097 2097 2097 2097 2097 2097 2097

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2218 2218 2218 2218 2218 2218 2218 2218 2218

# %% [markdown]
# -loading a month after date flights manually

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2349 2349 2349 2349 2349 2349 2349 2349 2349

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2479 2479 2479 2479 2479 2479 2479 2479 2479

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2609 2609 2609 2609 2609 2609 2609 2609 2609

# %% [markdown]
# -For Banglore to Chennai

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=MAA&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=1659607883905&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2644 2644 2644 2644 2644 2644 2644 2644 2644

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2703 2703 2703 2703 2703 2703 2703 2703 2703

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2771 2771 2771 2771 2771 2771 2771 2771 2771

# %% [markdown]
# -loading a month after date flights manually

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2850 2850 2850 2850 2850 2850 2850 2850 2850

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 2930 2930 2930 2930 2930 2930 2930 2930 2930

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3008 3008 3008 3008 3008 3008 3008 3008 3008

# %% [markdown]
# -For Ahmedabad to Hyderabad

# %%
driver.get("https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=04%2F08%2F2022&hb=0&noOfSegments=1&origin=AMD&originCountry=IN&type=O&unique=1488156879543&version=1.1&viewName=normal")

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[1]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3049 3049 3049 3049 3049 3049 3049 3049 3049

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[2]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3122 3122 3122 3122 3122 3122 3122 3122 3122

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[3]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3214 3214 3214 3214 3214 3214 3214 3214 3214

# %% [markdown]
# -loading a month after date flights manually

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[11]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3315 3315 3315 3315 3315 3315 3315 3315 3315

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[12]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3412 3412 3412 3412 3412 3412 3412 3412 3412

# %%
driver.execute_script("window.scrollTo(0, 0);")
time.sleep(1)
button = driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div")
button.click()

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(2)

#extracting airline name

try:
    for i in driver.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):      
        airline.append(i.text)
except NoSuchElementException:
    airline.append(np.nan)    

#extracting departure time

try:
    for i in driver.find_elements_by_xpath('//div[@class="fs-15 bold time"]'):
        depart.append(i.text)
except NoSuchElementException:
    depart.append(np.nan)    

#extracting arrival time

try:
    for i in driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
        arrival.append(i.text)
except NoSuchElementException:
    arrival.append(np.nan)
    
#extracing source city 

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b col-4 no-wrap text-right dtime col-3"]/p'):
        source.append(i.text)
except NoSuchElementException:
    source.append(np.nan)
        
#extracting destination city
    
try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]'):
        destination.append(i.text)
except NoSuchElementException:
    destination.append(np.nan)
    
    
#extracting duration

try:
    for i in driver.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
        duration.append(i.text)
except NoSuchElementException:
    duration.append(np.nan)
    
#extracting stops

try:
    for i in driver.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
        stops.append(i.text)
except NoSuchElementException:
    stops.append(np.nan)
        
#extratcing price

try:
    for i in driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
        price.append(i.text.replace('₹',' ').strip())
except NoSuchElementException:
    price.append(np.nan)

# %%
while len(airline)>len(date):
    date.append(driver.find_element_by_xpath("//ul[@class='full-width no-wrap ovf-hidden']/li[13]/div/p").text)

# %%
print(len(airline),len(depart),len(arrival),len(source),len(destination),len(duration),len(stops),len(price),len(date))
# Out:
# 3509 3509 3509 3509 3509 3509 3509 3509 3509

# %%
#forming a dataframe for the extracted data

df=pd.DataFrame({'Airline':airline,'Source':source,'Departure':depart,'Destination':destination,'Arrival':arrival,'Duration':duration,'Stop(s)':stops,'Date':date,'Fare':price})
df
# Out:
#         Airline     Source Departure Destination Arrival Duration    Stop(s)  \
# 0     Air India  New Delhi     20:00      Mumbai   22:10   2h 10m   Non Stop
# 1     Air India  New Delhi     19:00      Mumbai   21:15   2h 15m   Non Stop
# 2     Air India  New Delhi     21:15      Mumbai   23:35   2h 20m   Non Stop
# 3     Air India  New Delhi     17:55      Mumbai   22:10   4h 15m     1 Stop
# 4       Vistara  New Delhi     15:30      Mumbai   17:40   2h 10m   Non Stop
# ...         ...        ...       ...         ...     ...      ...        ...
# 3504    Vistara  Ahmedabad     08:30   Hyderabad   20:55  12h 25m  2 Stop(s)
# 3505    Vistara  Ahmedabad     08:30   Hyderabad   20:55  12h 25m  2 Stop(s)
# 3506  Air India  Ahmedabad     07:30   Hyderabad   21:40  14h 10m  2 Stop(s)
# 3507  Air India  Ahmedabad     07:30   Hyderabad   21:15  13h 45m  2 Stop(s)
# 3508  Air India  Ahmedabad     07:30   Hyderabad   21:40  14h 10m  3 Stop(s)
#
#             Date    Fare
# ...

# %%
df.to_excel('flightsfaredata.xlsx')         #saving to an excel file

# %%
#closing the driver

driver.close()
