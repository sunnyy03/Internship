# %%
#loading the dataset

import pandas as pd
import numpy as np

# %%
path=r'C:\Users\Yash Bhardwaj\Downloads\Customer_retention_dataset-\Customer_retention_dataset'
filename='customer_retention_dataset.xlsx'

# %%
df=pd.read_excel(r'C:\Users\Yash Bhardwaj\Downloads\Customer_retention_dataset-\Customer_retention_dataset\customer_retention_dataset.xlsx',sheet_name=0)

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df=df.iloc[:,:47]

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
#checking for null values

df.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - no null values are present

# %% [markdown]
# # EDA:

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# - there are more females users than male users

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['2 How old are you? '],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# - so most of the people are from age group 21-50 year, while 31-40 has most count

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['5 Since How Long You are Shopping Online ?'],hue=df['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# - so most customers who are shopping for more than 4 years are of age 31-40 years, while for 2-3 years, age group 41-50 years is most active

# %%
plt.figure(figsize=(12,5))
sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# - female customers are making more purchases in every range but most customers are making less than 10 online purchases a year

# %%
df['7 How do you access the internet while shopping on-line?'].unique()
# Out:
# array(['Dial-up', 'Wi-Fi', 'Mobile Internet', 'Mobile internet'],
#       dtype=object)

# %% [markdown]
# - okay so it can be seen that the data has some typos we will correct that first

# %%
df['7 How do you access the internet while shopping on-line?'].replace('Mobile internet','Mobile Internet',inplace=True)

# %%
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# - okay, so most cutomers mainly use mobile intrnet for online shopping, while close to zero people use dial-up for online shopping

# %%
sns.countplot(df['8 Which device do you use to access the online shopping?'],hue=df['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# - it can be seen that age group less than 20 years is using Smartphone only for online purchases, Tablet has least users, age group 21-30 years is highest in using smartphone for online purchasing while age group 31-40 is highest in laptop using

# %%
sns.countplot(df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '],hue=df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %% [markdown]
# - so it is clear that the customers mainly use smartphones for online shopping

# %%
sns.countplot(df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '],hue=df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %%
sns.countplot(df['11 What browser do you run on your device to access the website?\t\t\t                                                          '],hue=df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %% [markdown]
# - so mostly customers use google chrome browser from all the devices, while smartphone users use Safari browser

# %%
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '],hue=df['11 What browser do you run on your device to access the website?\t\t\t                                                          '])
# Out:
# <AxesSubplot:xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %% [markdown]
# - okay so search engine has the highest count while content marketing has least

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '],hue=df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# - most customers have used application to reach the online store mostly by smartphone users, while from search engine and direct url laptop users have a high count

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %% [markdown]
# - okay so for less than 1 minutes time taken female customer's count is high and more female customers spend more than 11 minutes to make a decision than male customers, moreover for 6-10 minutes time taken male customer have a higher count

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '],hue=df['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %% [markdown]
# - less than 20 years age group mostly prefer Cash on delivery method, while most customers prefer Credit/Debit card method specially 21-30 years age group customers, for E-wallets method age group 31-40 years has highest count

# %%
sns.countplot(df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# - okay so most customers abandon the shopping cart sometimes only

# %%
plt.figure(figsize=(13,5))
sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ', ylabel='count'>

# %% [markdown]
# - most customers believe in alternative offers

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['18 The content on the website must be easy to read and understand'],hue=df['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# - most customers are strongly agree which means the content is indeed easy to read and understand for all age groups

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'],hue=df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %% [markdown]
# - so most customers strongly agree on information provided on alternative options as useful in decision making

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# - okay so most customers agree only on the above statement, so a bond of trust with seller also is must needed

# %%
def count0(x):
    plt.figure(figsize=(10,5))
    sns.countplot(df[x])
    plt.show()

# %%
def count(x):
    plt.figure(figsize=(10,5))
    sns.countplot(df[x],hue=df[input()])
    plt.show()

# %%
count('21 All relevant information on listed products must be stated clearly')
# Out:
# 1Gender of respondent

# %% [markdown]
# - as most customer are agreeing on the statement, it is an important aspect

# %%
count('22 Ease of navigation in website')
# Out:
# 2 How old are you?

# %% [markdown]
# - this may mean that the website or application is easy to nevigate for almost all age groups

# %%
count('23 Loading and processing speed')
# Out:
# 7 How do you access the internet while shopping on-line?

# %% [markdown]
# - so it can be seen that customers who use wifi or mobile internet has no issues with loading and processing speed while customers using dial up are having these issues

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
count('24 User friendly Interface of the website')
# Out:
# 8 Which device do you use to access the online shopping?

# %% [markdown]
# - for smartphone users applications are available which means better UI while as seen before desktop users were using direct link or search engine for online purchasing they are having issues being friendly with the ui

# %%
count('25 Convenient Payment methods')
# Out:
# 2 How old are you?

# %% [markdown]
# - age group 31-40 years has highest count of customers being satisfied with mode of payments, second is 21-30 years age group, the highest count for disagreeing with convenient payment methods is for age group 41-50 years

# %%
count0('26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time')

# %% [markdown]
# - only a few customers are disagreeing which means bond of trust is present among the customers

# %%
count('27 Empathy (readiness to assist with queries) towards the customers')
# Out:
# 1Gender of respondent

# %% [markdown]
# - customer service is doing good

# %%
count('28 Being able to guarantee the privacy of the customer')
# Out:
# 2 How old are you?

# %% [markdown]
# - so most of the customers believe that their privacy is protected

# %%
count0('29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)')

# %% [markdown]
# - customer service is doing great

# %%
count('30 Online shopping gives monetary benefit and discounts')
# Out:
# 2 How old are you?

# %% [markdown]
# - okay, so most customers believe that online shopping guves benefit and discounts with age group 21-30 years having maximum count, while reasonable amount of customers believe in something not like this with age group 21-50, age group 41-50 years has most count for disagreeing that online shopping gives monetary benefits and discounts

# %%
count('31 Enjoyment is derived from shopping online')
# Out:
# 2 How old are you?

# %% [markdown]
# - it can be seen that customers who believe that enjoyment is derived from online shopping has highest count for age group 21-30 years, while 31-40 age group have indifferent beliefs, while age group 41-50 years has most count on strongly disagree.

# %%
count('32 Shopping online is convenient and flexible')
# Out:
# 2 How old are you?

# %% [markdown]
# - so must of the customers from all age group believe that online shopping is convenient andd flexible

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
count0('33 Return and replacement policy of the e-tailer is important for purchase decision')

# %% [markdown]
# - okay so it can be seen that return and replacement policy is an important aspect.

# %%
count('34 Gaining access to loyalty programs is a benefit of shopping online')
# Out:
# 2 How old are you?

# %% [markdown]
# - while most customers believe that shopping online gives you loyalty programs benefit with 41-50 years as highest count reasonable number of customers have indifferent opinion with 31-40 years as highest count

# %%
count0('35 Displaying quality Information on the website improves satisfaction of customers')

# %% [markdown]
# - most customers believe it improves the satisfaction, while some have indifferent opinion

# %%
count('36 User derive satisfaction while shopping on a good quality website or application')
# Out:
# 2 How old are you?

# %% [markdown]
# - it is an important as aspect it can be seen

# %%
count('37 Net Benefit derived from shopping online can lead to users satisfaction')
# Out:
# 2 How old are you?

# %% [markdown]
# - okay so most customers from all age group believe that benefit derived from online shopping leads to customer satisfaction

# %%
count0('38 User satisfaction cannot exist without trust')

# %% [markdown]
# - trust is one of the most important aspect of online shopping

# %%
count('39 Offering a wide variety of listed product in several category')
# Out:
# 1Gender of respondent

# %% [markdown]
# - so the more the better

# %%
count0('40 Provision of complete and relevant product information')

# %% [markdown]
# - it is a necessary aspect

# %%
count('41 Monetary savings')
# Out:
# 2 How old are you?

# %% [markdown]
# - as seen before as well most customers believe that online shopping moentary and other benefits

# %%
count0('42 The Convenience of patronizing the online retailer')

# %% [markdown]
# - it can be seen that this situation is not necessary for customer satsifaction or anything

# %%
count('43 Shopping on the website gives you the sense of adventure')
# Out:
# 2 How old are you?

# %% [markdown]
# - age group 41-50 years has strong opinion on this with highest count, most 31-40 years age group agree with this, on the other hand reasonable number of customers have indifferent opinion or they are diagreeing

# %%
count('44 Shopping on your preferred e-tailer enhances your social status')
# Out:
# 2 How old are you?

# %% [markdown]
# - most customers have indifferent opinion on this few customers strongly agree on this, moreover age group 21-30 years have highest count who would agree on this

# %%
count0('45 You feel gratification shopping on your favorite e-tailer')

# %% [markdown]
# so it is not true in most customers scenario but good number of customers would agree on this

# %%
count('46 Shopping on the website helps you fulfill certain roles')
# Out:
# 2 How old are you?

# %% [markdown]
# - so customers of age group 31-40 years believe it's true, age group 21-30 years have indifferent opinion on this with highest vote count

# %%
count('47 Getting value for money spent')
# Out:
# 2 How old are you?

# %% [markdown]
# - okay so this is one of the most important aspect of customer satisfaction it can be easily seen

# %%
df1=pd.read_excel(r'C:\Users\Yash Bhardwaj\Downloads\Customer_retention_dataset-\Customer_retention_dataset\customer_retention_dataset.xlsx',sheet_name=0)

# %%
df1=df1.iloc[:,47:]
df1
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
def vcount(x):
    return df1[x].value_counts()

# %%
vcount('Fast loading website speed of website and application')
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
for i in df1.columns:
    print(vcount(i),'\n')
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64
#
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# ...

# %% [markdown]
# - as it can be seen that amazon.in and flipkart.com have highest numbers of satisfactory customers, following by myntra.com and paytm.com
